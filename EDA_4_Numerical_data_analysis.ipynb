# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
file_path = "C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv"
file_path
# Out:
# 'C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv'

# %%
visa_df = pd.read_csv(file_path)
visa_df
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 0    EZYV00001    Europe           High School                  N
# 1    EZYV00002  North Am            Bachelor's                  N
# 2    EZYV00003      Asia           High School                  Y
# 3    EZYV00004  North Am            Bachelor's                  N
# 4    EZYV00005    Africa             Doctorate                  N
# ..         ...       ...                   ...                ...
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                       Y            12815         1986                South
# 1                       Y            58485         1955            Northeast
# 2                       Y            31262         1904              Midwest
# 3                       Y            42617         1993              Midwest
# 4                       Y            69628         1909            Northeast
# ..                    ...              ...          ...                  ...
# 195                     N            14629         2004                 West
# 196                     Y             7504         2012                 West
# 197                     Y            43149         1900                South
# 198                     Y           111098         1888                South
# 199                     N           140121         1981              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 0          100248.93         Year                  N   Certified
# 1           36080.79         Year                  Y   Certified
# 2          117927.92         Year                  N   Certified
# 3          110256.05         Hour                  N   Certified
# 4          135456.27         Hour                  Y      Denied
# ..               ...          ...                ...         ...
# 195         91543.97         Hour                  Y      Denied
# 196         80136.89         Hour                  Y      Denied
# 197        100729.22         Year                  N   Certified
# 198         74387.16         Year                  Y      Denied
# 199         46578.32         Year                  Y      Denied
#
# [200 rows x 12 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['prevailing_wage']   # Series
# Out:
# 0      100248.93
# 1       36080.79
# 2      117927.92
# 3      110256.05
# 4      135456.27
#          ...
# 195     91543.97
# 196     80136.89
# 197    100729.22
# 198     74387.16
# 199     46578.32
# Name: prevailing_wage, Length: 200, dtype: float64

# %%
visa_df['prevailing_wage'].values
# Out:
# array([100248.93,  36080.79, 117927.92, 110256.05, 135456.27, 145905.88,
#         55120.87,  71287.67, 129869.8 , 111859.19, 124064.18,  93976.01,
#        132684.56,  55114.74,  32508.72,  77223.39,  77344.56, 116006.58,
#         30070.73,  69373.6 , 113577.54,  87655.47,  90587.64, 144839.63,
#        108551.73, 131019.3 , 145128.76, 148423.43,  33490.9 ,  66311.92,
#        120208.59,  74216.68,  41522.71, 127039.5 , 124525.97, 144955.85,
#         39081.98, 122972.66,  80512.47, 107809.41,  71706.76, 125798.54,
#         85057.22,  73069.74,  51650.7 ,  64542.62,  50046.51, 114201.48,
#        140560.73,  72409.86,  40709.44, 147768.9 , 104931.92, 110057.44,
#         71583.76, 141889.69,  91687.89, 109554.31, 136617.36, 141249.86,
#        115249.65,  85725.07, 141697.55,  66065.04,  97660.5 ,  98739.87,
#         89596.78,  68906.02,  88214.65,  60950.32, 147143.31, 126785.22,
#         38089.88, 144385.97, 107345.82,  50569.92, 130022.43,  68918.29,
#         56992.46, 120652.75, 142096.36, 124027.27, 107889.32,  35501.74,
#         70420.22,  71816.78, 116745.69,  32676.59, 137372.38, 100875.02,
#         56242.66, 103858.34,  63866.67,  79781.45,  58484.93,  83150.37,
#        139851.71,  96374.45,  93050.14,  33649.83,  82819.99, 136324.45,
#        117356.8 , 110959.76, 110856.79, 145699.81,  64451.6 ,  60705.75,
#         87909.77,  65115.58,  62891.56,  93563.52,  95600.84, 121114.88,
#        124161.85,  32892.47,  94773.33,  50904.25,  75351.69,  93885.47,
#        135503.42,  97500.52,  64423.47, 119616.8 ,  49476.86,  80728.44,
#         62459.14, 121423.12,  74883.62,  51767.57, 123445.68,  39247.99,
#         65843.97,  57646.84, 136854.94, 131411.45,  74460.32, 131650.08,
#        102819.43, 109665.99, 132007.55,  67154.4 ,  59595.14,  91669.19,
#        124649.82, 109336.71,  50482.92,  46063.56, 119183.56, 112725.61,
#         62101.44, 120836.21, 122899.56, 101813.94, 148068.  ,  98420.9 ,
#         77235.53,  40561.31,  86756.41,  45257.94, 112096.43, 136077.61,
#         96210.3 ,  91130.36,  68819.29,  55343.65,  85274.79, 120662.09,
#         46409.51, 139901.61,  36190.34,  53525.22, 140997.34, 103558.34,
#         87889.43,  39284.26,  52214.01,  60814.16,  83040.93,  80993.64,
#         46170.11,  61987.6 , 102301.43,  87463.64, 138845.31,  59102.94,
#         40484.65,  95713.71,  71784.28, 142118.19,  36614.92, 147155.12,
#        137663.07,  66328.34, 123521.52,  91543.97,  80136.89, 100729.22,
#         74387.16,  46578.32])

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - count
# - min
# - max
# - mean
# - median

# %%
wage = visa_df['prevailing_wage']
wage.count()
# Out:
# 200

# %%
wage.min()
# Out:
# 30070.73

# %%
wage.max()
# Out:
# 148423.43

# %%
wage.mean()
# Out:
# 91937.0197

# %%
wage.median()
# Out:
# 91678.54000000001

# %%
dict1 = {}                                                    #creating empty dictionary
wage_count = round(visa_df['prevailing_wage'].count(),2)      # Counts how many values are in the column prevailing_wage and rounds it to 2 decimals.
wage_min = round(visa_df['prevailing_wage'].min(),2)          #Finds the minimum wage value and rounds it.
wage_max = round(visa_df['prevailing_wage'].max(),2)
wage_mean = round(visa_df['prevailing_wage'].mean(),2)                                                     #Finds the maximum wage value and rounds it.
wage_median = round(visa_df['prevailing_wage'].median(),2)    #Finds the median (middle) wage value and rounds it.
wage_std = round(visa_df['prevailing_wage'].std(),2)
dict1['count']=wage_count
dict1['min']=wage_min                                         #Stores all the calculated values into the dictionary with proper keys.
dict1['max']=wage_max
dict1['mean']=wage_mean
dict1['median']=wage_median
dict1['std']=wage_std
dict1                                                         #Displays the dictionary with results.
pd.DataFrame(dict1,index=['prevailing_wage'])                 #Converts the dictionary into a DataFrame (table) with one row named "prevailing_wage".
# Out:
#                  count       min        max      mean    median       std
# prevailing_wage    200  30070.73  148423.43  91937.02  91678.54  33715.17

# %%
wage_count = round(visa_df['prevailing_wage'].count(),2)      
wage_min = round(visa_df['prevailing_wage'].min(),2)          
wage_max = round(visa_df['prevailing_wage'].max(),2)
wage_mean = round(visa_df['prevailing_wage'].mean(),2)   
wage_median = round(visa_df['prevailing_wage'].median(),2)    
wage_std = round(visa_df['prevailing_wage'].std(),2)

list1 = [wage_count,wage_min,wage_max,wage_mean,wage_median,wage_std]

pd.DataFrame(list1,
             columns = ['prevailing_wage'],
             index = ['count','min','max','mean','median','std'])
# Out:
#         prevailing_wage
# count            200.00
# min            30070.73
# max           148423.43
# mean           91937.02
# median         91678.54
# std            33715.17

# %%
#step-1: numerical column list
dtypes=dict(visa_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)

dict1={}
for i in num:
    count=round(visa_df[i].count(),2)
    MIN=round(visa_df[i].min(),2)
    MAX=round(visa_df[i].max(),2)
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)
    list1=[count,MIN,MAX,mean,median,std]
    dict1[i]=list1

df=pd.DataFrame(dict1,
             index=['count','min','max','mean','median','std'])
dict1
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
# {'no_of_employees': [200, 693, 147663, 77312.69, 75295.5, 41787.3],
#  'yr_of_estab': [200, 1880, 2022, 1949.67, 1951.5, 40.93],
#  'prevailing_wage': [200, 30070.73, 148423.43, 91937.02, 91678.54, 33715.17]}

# %%
visa_df.describe()
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# count       200.000000   200.000000        200.00000
# mean      77312.690000  1949.670000      91937.01970
# std       41787.295918    40.933223      33715.17152
# min         693.000000  1880.000000      30070.73000
# 25%       43128.500000  1912.000000      64444.56750
# 50%       75295.500000  1951.500000      91678.54000
# 75%      112360.250000  1986.000000     120905.87750
# max      147663.000000  2022.000000     148423.43000

# %%
visa_df['prevailing_wage'].mean()      #reading a specific column and applying methods....like mean, mode, median...etc
# Out:
# 91937.0197

# %%
visa_df['prevailing_wage'].median()
# Out:
# 91678.54000000001

# %%
visa_df['prevailing_wage'].mode()
# Out:
# 0       30070.73
# 1       32508.72
# 2       32676.59
# 3       32892.47
# 4       33490.90
#          ...
# 195    147143.31
# 196    147155.12
# 197    147768.90
# 198    148068.00
# 199    148423.43
# Name: prevailing_wage, Length: 200, dtype: float64

# %% [markdown]
# *****percentile and quantile*****

# %% [markdown]
# - percentile range from 1 to 100
# - quantile q1 = 25p, q2 = 50p, q3 = 75p
# - np.percentile(<direct number between 1 to 100>, data)
# - example = np.percentile(75,data)
# - np.quantile(<decimal number>, data)
# - example = np.quantile(0.75,data)

# %%
q1 = round(np.percentile(visa_df['prevailing_wage'],25),2)
q2 = round(np.percentile(visa_df['prevailing_wage'],50),2)
q3 = round(np.percentile(visa_df['prevailing_wage'],75),2)
print(q1,q2,q3)
# Out:
# 64444.57 91678.54 120905.88

# %%
q1 = round(np.quantile(visa_df['prevailing_wage'],0.25),2)
q2 = round(np.quantile(visa_df['prevailing_wage'],0.50),2)
q3 = round(np.quantile(visa_df['prevailing_wage'],0.75),2)
print(q1,q2,q3)
# Out:
# 64444.57 91678.54 120905.88

# %%
dtypes=dict(visa_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)

dict1={}
for i in num:
    count=round(visa_df[i].count(),2)
    MIN=round(visa_df[i].min(),2)
    MAX=round(visa_df[i].max(),2)
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)
    ###########################################################
    q1 = round(np.percentile(visa_df[i],0.25),2)
    q2 = round(np.percentile(visa_df[i],0.50),2)
    q3 = round(np.percentile(visa_df[i],0.75),2)

    
    list1=[count,MIN,MAX,mean,median,std,q1,q2,q3]
    dict1[i]=list1

    df=pd.DataFrame(dict1,
                 index=['count','min','max','mean','median','std','25','50','75'])
dict1
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
# {'no_of_employees': [200,
#   693,
#   147663,
#   77312.69,
#   75295.5,
#   41787.3,
#   806.93,
#   920.86,
#   1229.32],
#  'yr_of_estab': [200,
#   1880,
#   2022,
#   1949.67,
#   1951.5,
#   40.93,
#   1880.0,
#   1880.0,
#   1880.49],
#  'prevailing_wage': [200,
#   30070.73,
#   148423.43,
#   91937.02,
#   91678.54,
#   33715.17,
#   31283.63,
#   32496.53,
#   32591.4]}

# %% [markdown]
# df

# %%
q1 = round(np.percentile(visa_df['prevailing_wage'],25),2)
q1
# Out:
# 64444.57

# %%
25*156192.00/100
# Out:
# 39048.0

# %% [markdown]
# ******here what is the meaning of that value 64444.57 is ?******
#
# ******25% of data below 64444.57******
#
# ******25% of the observations from the total data have a value below 64444.57******

# %%
visa_df['prevailing_wage'].count()
# Out:
# 200

# %%
25*200/100
# Out:
# 50.0

# %%
len([visa_df['prevailing_wage']<64444.57])
# Out:
# 1

# %% [markdown]
# $Empiricle$-$rule$

# %% [markdown]
# <img src="https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/1_empirical-rule.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 810px; height: 152px; margin: 0px; width: 304px;" alt="Empirical Rule (68-95-99.7) Explained | Built In" jsname="kn3ccd">

# %% [markdown]
# **when data shows a normal distribution**
# - u-1*sigma to u+1*sigma : 68%
# - u-2*sigma to u+2*sigma : 95%
# - u-3*sigma to u+3*sigma : 99.7%

# %%
wage_mean,  wage_std
# Out:
# (91937.02, 33715.17)

# %%
# wage_mean = u
# wage_std = sigma

# %%
val_minus_1 = round(wage_mean-1*wage_std,2)
val_plus_1 = round(wage_mean+1*wage_std,2)
val_minus_2 = round(wage_mean-2*wage_std,2)
val_plus_2 = round(wage_mean+2*wage_std,2)
val_minus_3 = round(wage_mean-3*wage_std,2)
val_plus_3 = round(wage_mean+3*wage_std,2)

print(val_minus_1,val_plus_1,val_minus_2,val_plus_2,val_minus_3,val_plus_3)
# Out:
# 58221.85 125652.19 24506.68 159367.36 -9208.49 193082.53

# %% [markdown]
# - 68 percentage of the observations have values between [58221.85  to  125652.19]
#
# - 95 percentage of the observations have values between [24506.68  to 159367.36]
#
# - 99.7 percentage of the observations have values between [-9208.49 to  193082.53]

# %%
68*200/100
# Out:
# 136.0

# %%
con1 = visa_df['prevailing_wage']>val_minus_1
con2 = visa_df['prevailing_wage']<val_plus_1
len(visa_df[con1 & con2])
# Out:
# 123

# %%
len(visa_df[con1 & con2])/len(visa_df)
# Out:
# 0.615

# %% [markdown]
# - 68% should fall between (u - sigma) and (u + sigma) when data is normal. #(according to the above image)
# - But.....
# - the above data ste is not normal, so only 19.5% fall in that range. #(according to my data 19.5%)

# %%
con3 = visa_df['prevailing_wage']>val_minus_2
con4 = visa_df['prevailing_wage']<val_plus_2
len(visa_df[con3 & con4])
# Out:
# 200

# %%
len(visa_df[con3 & con4])/len(visa_df)
# Out:
# 1.0

# %%
con5 = visa_df['prevailing_wage']>val_minus_3
con6 = visa_df['prevailing_wage']<val_plus_3
len(visa_df[con5 & con6])
# Out:
# 200

# %%
len(visa_df[con5 & con6])/len(visa_df)
# Out:
# 1.0

# %%
pyplot.hist(visa_df['prevailing_wage'],)
#By default it will give 10 intervals
# if you want more use bins
# Out:
# (array([18., 14., 21., 25., 17., 22., 20., 24., 14., 25.]),
#  array([ 30070.73,  41906.  ,  53741.27,  65576.54,  77411.81,  89247.08,
#         101082.35, 112917.62, 124752.89, 136588.16, 148423.43]),
#  <BarContainer object of 10 artists>)

# %%
pyplot.hist(visa_df['prevailing_wage'],bins=50)
# Out:
# (array([1., 5., 4., 4., 4., 0., 5., 0., 5., 4., 3., 3., 5., 5., 5., 5., 4.,
#         7., 5., 4., 0., 5., 3., 4., 5., 4., 6., 4., 4., 4., 3., 3., 3., 6.,
#         5., 3., 3., 3., 6., 9., 3., 0., 5., 2., 4., 5., 5., 4., 6., 5.]),
#  array([ 30070.73 ,  32437.784,  34804.838,  37171.892,  39538.946,
#          41906.   ,  44273.054,  46640.108,  49007.162,  51374.216,
#          53741.27 ,  56108.324,  58475.378,  60842.432,  63209.486,
#          65576.54 ,  67943.594,  70310.648,  72677.702,  75044.756,
#          77411.81 ,  79778.864,  82145.918,  84512.972,  86880.026,
#          89247.08 ,  91614.134,  93981.188,  96348.242,  98715.296,
#         101082.35 , 103449.404, 105816.458, 108183.512, 110550.566,
#         112917.62 , 115284.674, 117651.728, 120018.782, 122385.836,
#         124752.89 , 127119.944, 129486.998, 131854.052, 134221.106,
#         136588.16 , 138955.214, 141322.268, 143689.322, 146056.376,
#         148423.43 ]),
#  <BarContainer object of 50 artists>)

# %%
# it is the above output, now we are going to analyse that
(array([1., 5., 4., 4., 4., 0., 5., 0., 5., 4., 3., 3., 5., 5., 5., 5., 4.,
        7., 5., 4., 0., 5., 3., 4., 5., 4., 6., 4., 4., 4., 3., 3., 3., 6.,
        5., 3., 3., 3., 6., 9., 3., 0., 5., 2., 4., 5., 5., 4., 6., 5.]),
 array([ 30070.73 ,  32437.784,  34804.838,  37171.892,  39538.946, # these are the intervals (50 intervals)
         41906.   ,  44273.054,  46640.108,  49007.162,  51374.216,
         53741.27 ,  56108.324,  58475.378,  60842.432,  63209.486,
         65576.54 ,  67943.594,  70310.648,  72677.702,  75044.756,
         77411.81 ,  79778.864,  82145.918,  84512.972,  86880.026,
         89247.08 ,  91614.134,  93981.188,  96348.242,  98715.296,
        101082.35 , 103449.404, 105816.458, 108183.512, 110550.566,
        112917.62 , 115284.674, 117651.728, 120018.782, 122385.836,
        124752.89 , 127119.944, 129486.998, 131854.052, 134221.106,
        136588.16 , 138955.214, 141322.268, 143689.322, 146056.376,
        148423.43 ]),
 <BarContainer object of 50 artists>)

# %% [markdown]
# - 1 observations are between 30070.73 ,  32437.784
#
# - 5 observations are between 32437.784,  34804.838
#
# - 4 observations are between 34804.838,  37171.892
# - etc

# %%
#1 observations are between 30070.73 , 32437.784

#5 observations are between 32437.784, 34804.838

#4 observations are between 34804.838, 37171.892

# to verify this by conditions

cond1 = visa_df['prevailing_wage']>32437.784
cond2 = visa_df['prevailing_wage']<34804.838
cond1&cond2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: prevailing_wage, Length: 200, dtype: bool

# %%
len(visa_df[cond1&cond2])
# Out:
# 5

# %%
# Instead of doing that all cond1...cond2... code like this
len(visa_df[visa_df['prevailing_wage'].between(32437.784,34804.838)])
# Out:
# 5
